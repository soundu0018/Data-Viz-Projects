# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/soundaryakoganty/Desktop/Msc Business Analytics/BA viz for managers & consultants/datasets/vgsales.csv', index_col=0)

# %%
df.sample(5)
# Out:
#                                                   Name Platform    Year  \
# Rank
# 3749                   Epic Mickey 2: The Power of Two     X360  2012.0
# 639                                         Ice Hockey      NES  1988.0
# 6929                      Pictionary: Ultimate Edition     X360  2011.0
# 10132                          Pac-Man Pinball Advance      GBA  2005.0
# 14080  NHRA Drag Racing: Countdown to the Championship      PS2  2007.0
#
#         Genre                   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# 3749   Action  Disney Interactive Studios      0.32      0.17      0.00
# 639    Sports                    Nintendo      1.27      0.32      0.78
# 6929     Misc                         THQ      0.16      0.05      0.00
# 10132    Misc      Zoo Digital Publishing      0.08      0.03      0.00
# 14080  Racing                         THQ      0.02      0.01      0.00
#
#        Other_Sales  Global_Sales
# Rank
# 3749          0.04          0.54
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16291 non-null  object
#  1   Platform      16291 non-null  category
#  2   Year          16291 non-null  float64
#  3   Genre         16291 non-null  object
#  4   Publisher     16291 non-null  category
#  5   NA_Sales      16291 non-null  float64
#  6   EU_Sales      16291 non-null  float64
#  7   JP_Sales      16291 non-null  float64
#  8   Other_Sales   16291 non-null  float64
#  9   Global_Sales  16291 non-null  float64
# dtypes: category(2), float64(6), object(2)
# memory usage: 1.2+ MB

# %%
df.head(5)
# Out:
#                           Name Platform    Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006.0        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# 2        29.08      3.58      6.81         0.77         40.24
# 3        15.85     12.88      3.79         3.31         35.82
# 4        15.75     11.01      3.28         2.96         33.00
# 5        11.27      8.89     10.22         1.00         31.37

# %%
df.sort_values(by='Global_Sales',ascending=True).head(5)
# Out:
#                                          Name Platform    Year      Genre  \
# Rank
# 16600                        Spirits & Spells      GBA  2003.0   Platform
# 16191                        Toro to Morimori      PS3  2009.0       Misc
# 16190                          Jewel Quest II       PC  2007.0     Puzzle
# 16189                             BattleForge       PC  2009.0   Strategy
# 16188  Tantei Jinguuji Saburo: Hai to Diamond      PSP  2009.0  Adventure
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 16600                      Wanadoo      0.01      0.00      0.00          0.0
# 16191  Sony Computer Entertainment      0.00      0.00      0.01          0.0
# 16190                    Avanquest      0.00      0.01      0.00          0.0
# 16189              Electronic Arts      0.00      0.01      0.00          0.0
# 16188             Arc System Works      0.00      0.00      0.01          0.0
#
#        Global_Sales
# Rank
# ...

# %%
df['Publisher'].count()
# Out:
# 16540

# %%
df['Platform'].count()
# Out:
# 16598

# %%
df["Publisher"]=df['Publisher'].astype('category')
df['Publisher'].describe()
# Out:
# count               16540
# unique                578
# top       Electronic Arts
# freq                 1351
# Name: Publisher, dtype: object

# %%
df['Platform']=df['Platform'].astype('category')
df['Platform'].describe()
# Out:
# count     16598
# unique       31
# top          DS
# freq       2163
# Name: Platform, dtype: object

# %%
EA = df[df['Publisher']=='Electronic Arts']
EA.head(5)
# Out:
#                               Name Platform    Year       Genre  \
# Rank
# 78                         FIFA 16      PS4  2015.0      Sports
# 83                  FIFA Soccer 13      PS3  2012.0      Action
# 84                      The Sims 3       PC  2009.0  Simulation
# 93    Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# 100                  Battlefield 3     X360  2011.0     Shooter
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 78    Electronic Arts      1.11      6.06      0.06         1.26          8.49
# 83    Electronic Arts      1.06      5.05      0.13         2.01          8.24
# 84    Electronic Arts      0.98      6.42      0.00         0.71          8.11
# 93    Electronic Arts      2.93      3.29      0.22         1.23          7.67
# 100   Electronic Arts      4.46      2.13      0.06         0.69          7.34

# %%
EA
# Out:
#                                Name Platform    Year       Genre  \
# Rank
# 78                          FIFA 16      PS4  2015.0      Sports
# 83                   FIFA Soccer 13      PS3  2012.0      Action
# 84                       The Sims 3       PC  2009.0  Simulation
# 93     Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# 100                   Battlefield 3     X360  2011.0     Shooter
# ...                             ...      ...     ...         ...
# 16342    Command & Conquer Renegade       PC  2002.0     Shooter
# 16387             Poker for Dummies       PC  2008.0        Misc
# 16416      The Godfather (JP sales)     X360  2006.0      Action
# 16542     Spore Galactic Adventures       PC  2009.0    Strategy
# 16557             Psychic Detective       PS  1995.0   Adventure
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 78     Electronic Arts      1.11      6.06      0.06         1.26
# ...

# %%
EA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1351 entries, 78 to 16557
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1351 non-null   object
#  1   Platform      1351 non-null   category
#  2   Year          1339 non-null   float64
#  3   Genre         1351 non-null   object
#  4   Publisher     1351 non-null   category
#  5   NA_Sales      1351 non-null   float64
#  6   EU_Sales      1351 non-null   float64
#  7   JP_Sales      1351 non-null   float64
#  8   Other_Sales   1351 non-null   float64
#  9   Global_Sales  1351 non-null   float64
# dtypes: category(2), float64(6), object(2)
# memory usage: 120.9+ KB

# %%
EA = EA.sort_values(by='Year', ascending=True)
EA
# Out:
#                                             Name Platform    Year       Genre  \
# Rank
# 12528                                  Syndicate       PC  1992.0    Strategy
# 3507                                  Theme Park       PS  1994.0  Simulation
# 11283                                 Theme Park      SAT  1994.0  Simulation
# 5642                             Extreme Pinball       PS  1995.0        Misc
# 2070   Road & Track Presents: The Need for Speed       PS  1995.0      Racing
# ...                                          ...      ...     ...         ...
# 3755                           NBA Street Vol. 2       GC     NaN      Sports
# 4201                     Tiger Woods PGA Tour 07      Wii     NaN      Sports
# 5164                               NBA Live 2003       XB     NaN      Sports
# 5903                               NBA Live 2003       GC     NaN      Sports
# 7650                                Dead Space 3       PC     NaN      Action
#
# ...

# %%
EA['Year'].describe()
# Out:
# count    1339.000000
# mean     2006.394324
# std         4.612309
# min      1992.000000
# 25%      2003.000000
# 50%      2007.000000
# 75%      2010.000000
# max      2016.000000
# Name: Year, dtype: float64

# %%
EA.isna().sum()
# Out:
# Name             0
# Platform         0
# Year            12
# Genre            0
# Publisher        0
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %%
df1 = df.groupby(['Publisher']).mean().sort_values(by='Global_Sales', ascending=False).head(50)

# %%
df1[df1['Year']>2000].head(20)
# Out:
#                                                Year  NA_Sales  EU_Sales  \
# Publisher
# Nintendo                                2003.830460  1.161977  0.595647
# RedOctane                               2005.750000  1.610000  0.327500
# Valve                                   2011.000000  0.830000  0.630000
# Hello Games                             2016.000000  0.580000  0.740000
# Sony Computer Entertainment Europe      2011.933333  0.597333  0.600000
# Microsoft Game Studios                  2006.746032  0.821958  0.363016
# Black Label Games                       2002.000000  0.590000  0.460000
# Bethesda Softworks                      2011.014493  0.559437  0.432817
# Valve Software                          2010.333333  0.580000  0.383333
# LucasArts                               2005.966292  0.555222  0.295889
# Take-Two Interactive                    2008.116505  0.533874  0.286053
# Sony Computer Entertainment             2004.448680  0.388316  0.274846
# ...

# %%
df2 = df[df['Year']>=2000]
df2
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 7                                 New Super Mario Bros.       DS  2006.0
# 8                                              Wii Play      Wii  2006.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#           Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
df2.groupby(['Publisher']).mean().sort_values(by='Global_Sales', ascending=False).head(20)
# Out:
#                                            Year  NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo                            2007.453333  0.943181  0.614648  0.543695
# RedOctane                           2005.750000  1.610000  0.327500  0.007500
# Valve                               2011.000000  0.830000  0.630000  0.020000
# Hello Games                         2016.000000  0.580000  0.740000  0.020000
# Sony Computer Entertainment Europe  2011.933333  0.597333  0.600000  0.166667
# Microsoft Game Studios              2006.844920  0.813476  0.357433  0.017433
# Black Label Games                   2002.000000  0.590000  0.460000  0.000000
# Bethesda Softworks                  2011.014493  0.571449  0.441739  0.020870
# SquareSoft                          2001.000000  0.305000  0.142500  0.661250
# Valve Software                      2010.333333  0.580000  0.383333  0.003333
# Take-Two Interactive                2008.443609  0.541378  0.283534  0.014511
# ...

# %%
df = df.dropna()
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
print(df.duplicated())
# Out:
# Rank
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 16596    False
# 16597    False
# 16598    False
# 16599    False
# 16600    False
# Length: 16291, dtype: bool

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
df1 = df.groupby(['Publisher']).mean().sort_values(by='Global_Sales', ascending=False).head(50)
df2 = df[df['Year']>=2000]

# %%
df2.sample(5)
# Out:
#                              Name Platform    Year     Genre  \
# Rank
# 2078             Wheel of Fortune      Wii  2010.0      Misc
# 4892   Monster Jam: Urban Assault       DS  2008.0    Racing
# 4345                  TNA iMPACT!     X360  2008.0  Fighting
# 8484                  Gunslingers      Wii  2010.0   Shooter
# 12692            Noddy in Toyland       DS  2011.0      Misc
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 2078                  THQ      0.89      0.04       0.0         0.06
# 4892           Activision      0.37      0.00       0.0         0.03
# 4345         Midway Games      0.26      0.15       0.0         0.04
# 8484   Neko Entertainment      0.08      0.06       0.0         0.02
# 12692                 GSP      0.00      0.05       0.0         0.01
#
#        Global_Sales
# Rank
# 2078           1.00
# 4892           0.39
# 4345           0.45
# 8484           0.16
# 12692          0.06

# %%
df2 = df2.drop_duplicates()
df2.to_csv('df2.csv', index=False)

# %%
df2.to_excel('df2.xlsx', sheet_name='vgs_full')

# %%
dfs = df2.groupby(['Publisher']).mean().sort_values(by='Global_Sales', ascending=False).head(20)
dfs
# Out:
#                                            Year  NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo                            2007.453333  0.943181  0.614648  0.543695
# RedOctane                           2005.750000  1.610000  0.327500  0.007500
# Valve                               2011.000000  0.830000  0.630000  0.020000
# Hello Games                         2016.000000  0.580000  0.740000  0.020000
# Sony Computer Entertainment Europe  2011.933333  0.597333  0.600000  0.166667
# Microsoft Game Studios              2006.844920  0.813476  0.357433  0.017433
# Black Label Games                   2002.000000  0.590000  0.460000  0.000000
# Bethesda Softworks                  2011.014493  0.571449  0.441739  0.020870
# SquareSoft                          2001.000000  0.305000  0.142500  0.661250
# Valve Software                      2010.333333  0.580000  0.383333  0.003333
# Take-Two Interactive                2008.443609  0.541378  0.283534  0.014511
# ...

# %%
dfs.to_excel('publisher_sales.xlsx', sheet_name='global_sales_avg')

# %%
dfc = df2['Publisher'].value_counts().head(20)
print(dfc)
# Out:
# Electronic Arts                           1231
# Activision                                 910
# Ubisoft                                    899
# Namco Bandai Games                         840
# Konami Digital Entertainment               698
# THQ                                        688
# Sony Computer Entertainment                527
# Nintendo                                   525
# Sega                                       516
# Take-Two Interactive                       399
# Capcom                                     326
# Tecmo Koei                                 312
# Atari                                      297
# Square Enix                                231
# Warner Bros. Interactive Entertainment     217
# Disney Interactive Studios                 213
# 505 Games                                  192
# Microsoft Game Studios                     187
# D3Publisher                                182
# Midway Games                               174
# ...

# %%
dfc.to_excel('publisher.xlsx')

# %%
df3 = df2.loc[df2['Publisher'].isin(['Nintendo','RedOctane','Valve','Hello Games','Sony Computer Entertainment Europe','Microsoft Game Studios','Black Label Games','Bethesda Softworks','SquareSoft','Valve Software','Take-Two Interactive','LucasArts','Enix Corporation', 'TalonSoft', 'mixi, Inc','Universal Interactive','Illusion Softworks', 'Sony Computer Entertainment','Electronic Arts','Activision'])]
df3.sample(5)
# Out:
#                               Name Platform    Year    Genre  \
# Rank
# 12336  Famicom Mini: Balloon Fight      GBA  2004.0   Action
# 3945    Wolfenstein: The New Order      PS3  2014.0  Shooter
# 6097                    Links 2004       XB  2003.0   Sports
# 3587   Need for Speed: Most Wanted       GC  2005.0   Racing
# 10033              SingStar Latino      PS3  2009.0     Misc
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 12336                     Nintendo      0.00      0.00      0.06         0.00
# 3945            Bethesda Softworks      0.14      0.25      0.02         0.09
# 6097        Microsoft Game Studios      0.21      0.06      0.00         0.01
# 3587               Electronic Arts      0.43      0.11      0.00         0.02
# 10033  Sony Computer Entertainment      0.11      0.00      0.00         0.01
#
#        Global_Sales
# Rank
# 12336          0.06
# 3945           0.51
# 6097           0.29
# 3587           0.56
# ...

# %%
print(df3.loc[df3['Publisher']=='Electronic Arts'])
# Out:
#                                Name Platform    Year       Genre  \
# Rank
# 78                          FIFA 16      PS4  2015.0      Sports
# 83                   FIFA Soccer 13      PS3  2012.0      Action
# 84                       The Sims 3       PC  2009.0  Simulation
# 93     Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# 100                   Battlefield 3     X360  2011.0     Shooter
# ...                             ...      ...     ...         ...
# 16189                   BattleForge       PC  2009.0    Strategy
# 16342    Command & Conquer Renegade       PC  2002.0     Shooter
# 16387             Poker for Dummies       PC  2008.0        Misc
# 16416      The Godfather (JP sales)     X360  2006.0      Action
# 16542     Spore Galactic Adventures       PC  2009.0    Strategy
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 78     Electronic Arts      1.11      6.06      0.06         1.26
# ...

# %%
df3
# Out:
#                                                     Name Platform    Year  \
# Rank
# 1                                             Wii Sports      Wii  2006.0
# 3                                         Mario Kart Wii      Wii  2008.0
# 4                                      Wii Sports Resort      Wii  2009.0
# 7                                  New Super Mario Bros.       DS  2006.0
# 8                                               Wii Play      Wii  2006.0
# ...                                                  ...      ...     ...
# 16540                    Transformers: Fall of Cybertron       PC  2012.0
# 16542                          Spore Galactic Adventures       PC  2009.0
# 16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS  2015.0
# 16571                                        XI Coliseum      PSP  2006.0
# 16598   SCORE International Baja 1000: The Official Game      PS2  2008.0
#
# ...

# %%
df3.to_excel('df3.xlsx', sheet_name='vgs_clean')
